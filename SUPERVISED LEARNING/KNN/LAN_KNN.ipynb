# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('loan_approval_dataset.csv')
X = df.drop(columns='Loan_Approved')
y = df['Loan_Approved']
df
# Out:
#      Age  Salary  Credit_Score  Loan_Amount  Loan_Term Employment_Status  \
# 0     56  136748           584        38209  36 months          Employed
# 1     46   25287           815        27424  24 months     Self-Employed
# 2     32  146593           398        42396  12 months        Unemployed
# 3     60   54387           696        11370  24 months        Unemployed
# 4     25   28512           788        14528  12 months          Employed
# ..   ...     ...           ...          ...        ...               ...
# 995   22   49241           500        41020  24 months     Self-Employed
# 996   40  116214           423        12415  48 months     Self-Employed
# 997   27   64569           300        28155  36 months     Self-Employed
# 998   61   31745           490        48884  12 months     Self-Employed
# 999   19   46029           815        21964  24 months          Employed
#
#     Residence_Type Previous_Default Loan_Approved
# 0            Owned              Yes           Yes
# 1           Rented               No           Yes
# 2           Rented              Yes           Yes
# 3            Owned               No            No
# 4            Owned               No            No
# ..             ...              ...           ...
# 995          Owned               No           Yes
# 996          Owned               No           Yes
# 997         Rented              Yes           Yes
# 998       Mortgage               No           Yes
# 999       Mortgage              Yes            No
#
# [1000 rows x 9 columns]

# %%
import seaborn as sns
sns.boxplot(X)
# Out:
# <Axes: >

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
y.value_counts()
# Out:
# Loan_Approved
# Yes    508
# No     492
# Name: count, dtype: int64

# %%
num_cols = X.select_dtypes(include='number').columns
obj_cols = X.select_dtypes(include='object').columns
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6704\2146109923.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_cols = X.select_dtypes(include='object').columns

# %%
preprocessing = ColumnTransformer(
    transformers=[
        ('scaling',StandardScaler(),num_cols),
        ('encoder',OneHotEncoder(),obj_cols)
    ]
)

main_pipe = Pipeline(
    steps=[
        ('pre',preprocessing),
        ('model',KNeighborsClassifier())
    ]
)
# main_pipe.fit(xtrain,ytrain)

# %%
grid_cv = GridSearchCV(
    estimator=main_pipe,
    param_grid={
        'model__n_neighbors' :[3,7,25,27,29,31],
        'model__metric':['manhattan','euclidean']
    },
    cv=5,
    n_jobs=-1
)
grid_cv.fit(xtrain,ytrain)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [    nan     nan     nan     nan     nan     nan 0.51    0.4675  0.48125
#  0.48375 0.46875 0.47625]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('pre',
#                                         ColumnTransformer(transformers=[('scaling',
#                                                                          StandardScaler(),
#                                                                          Index(['Age', 'Salary', 'Credit_Score', 'Loan_Amount'], dtype='str')),
#                                                                         ('encoder',
#                                                                          OneHotEncoder(),
#                                                                          Index(['Loan_Term', 'Employment_Status', 'Residence_Type', 'Previous_Default'], dtype='str'))])),
#                                        ('model', KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'model__metric': ['manhattan', 'euclidean'],
#                          'model__n_neighbors': [3, 7, 25, 27, 29, 31]})

# %%
res = grid_cv.cv_results_
pd.DataFrame(res)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.080912      0.022969         0.077232        0.020272
# 1        0.097594      0.027675         0.064085        0.011642
# 2        0.105404      0.016252         0.056939        0.009451
# 3        0.055634      0.016915         0.025431        0.001659
# 4        0.043233      0.001350         0.030878        0.006280
# 5        0.043986      0.006625         0.030335        0.004390
# 6        0.047764      0.008816         0.035852        0.012389
# 7        0.058646      0.013687         0.032455        0.003515
# 8        0.043938      0.004265         0.030261        0.001916
# 9        0.041769      0.003171         0.030854        0.001343
# 10       0.041321      0.005912         0.031773        0.002447
# 11       0.038989      0.003357         0.027866        0.006878
#
#    param_model__metric  param_model__n_neighbors  \
# 0            manhattan                         3
# 1            manhattan                         7
# 2            manhattan                        25
# 3            manhattan                        27
# 4            manhattan                        29
# 5            manhattan                        31
# 6            euclidean                         3
# 7            euclidean                         7
# 8            euclidean                        25
# 9            euclidean                        27
# 10           euclidean                        29
# 11           euclidean                        31
#
#                                                params  split0_test_score  \
# 0   {'model__metric': 'manhattan', 'model__n_neigh...                NaN
# 1   {'model__metric': 'manhattan', 'model__n_neigh...                NaN
# 2   {'model__metric': 'manhattan', 'model__n_neigh...                NaN
# 3   {'model__metric': 'manhattan', 'model__n_neigh...                NaN
# 4   {'model__metric': 'manhattan', 'model__n_neigh...                NaN
# 5   {'model__metric': 'manhattan', 'model__n_neigh...                NaN
# 6   {'model__metric': 'euclidean', 'model__n_neigh...            0.48750
# 7   {'model__metric': 'euclidean', 'model__n_neigh...            0.46250
# 8   {'model__metric': 'euclidean', 'model__n_neigh...            0.42500
# 9   {'model__metric': 'euclidean', 'model__n_neigh...            0.43750
# 10  {'model__metric': 'euclidean', 'model__n_neigh...            0.41875
# 11  {'model__metric': 'euclidean', 'model__n_neigh...            0.43125
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6             0.53125            0.51875            0.56250
# 7             0.46875            0.48125            0.51250
# 8             0.48125            0.55625            0.49375
# 9             0.45625            0.58750            0.49375
# 10            0.46250            0.54375            0.48125
# 11            0.46875            0.55000            0.50625
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                7
# 1                 NaN              NaN             NaN                7
# 2                 NaN              NaN             NaN                7
# 3                 NaN              NaN             NaN                7
# 4                 NaN              NaN             NaN                7
# 5                 NaN              NaN             NaN                7
# 6             0.45000          0.51000        0.038446                1
# 7             0.41250          0.46750        0.032452                6
# 8             0.45000          0.48125        0.044546                3
# 9             0.44375          0.48375        0.055424                2
# 10            0.43750          0.46875        0.043120                5
# 11            0.42500          0.47625        0.047004                4

# %%
grid_cv.best_params_
# Out:
# {'model__metric': 'euclidean', 'model__n_neighbors': 3}
